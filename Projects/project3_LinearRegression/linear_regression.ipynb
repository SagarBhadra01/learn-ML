# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset
df = pd.read_csv('ford.csv')

# %%
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
df.shape
# Out:
# (17966, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17966 entries, 0 to 17965
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         17966 non-null  object
#  1   year          17966 non-null  int64
#  2   price         17966 non-null  int64
#  3   transmission  17966 non-null  object
#  4   mileage       17966 non-null  int64
#  5   fuelType      17966 non-null  object
#  6   tax           17966 non-null  int64
#  7   mpg           17966 non-null  float64
#  8   engineSize    17966 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#                year         price  ...           mpg    engineSize
# count  17966.000000  17966.000000  ...  17966.000000  17966.000000
# mean    2016.866470  12279.534844  ...     57.906980      1.350807
# std        2.050336   4741.343657  ...     10.125696      0.432367
# min     1996.000000    495.000000  ...     20.800000      0.000000
# 25%     2016.000000   8999.000000  ...     52.300000      1.000000
# 50%     2017.000000  11291.000000  ...     58.900000      1.200000
# 75%     2018.000000  15299.000000  ...     65.700000      1.500000
# max     2060.000000  54995.000000  ...    201.800000      5.000000
#
# [8 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
#EDA for price
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], bins=30, kde=True)
plt.title('Distribution of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.boxplot(data=df, x='year', y='price')
plt.title('Boxplot of Price by Year')
plt.xlabel('Price')
plt.ylabel('Year')
plt.show()

# %%
sns.scatterplot(data=df, x='mileage', y='price')
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %%
sns.boxplot(data=df, x='engineSize', y='price')
# Out:
# <Axes: xlabel='engineSize', ylabel='price'>

# %%
sns.boxplot(data=df, x='transmission', y='price')
# Out:
# <Axes: xlabel='transmission', ylabel='price'>

# %%
sns.boxplot(data=df, x='fuelType', y='price')
# Out:
# <Axes: xlabel='fuelType', ylabel='price'>

# %%
sns.boxplot(data=df, x='model', y='price')
rotate_labels = plt.xticks(rotation=90)

# %%
sns.scatterplot(data=df, x='price', y='tax')
# Out:
# <Axes: xlabel='price', ylabel='tax'>

# %%
sns.scatterplot(data=df, x='price', y='mpg')
# Out:
# <Axes: xlabel='price', ylabel='mpg'>

# %%
x = df.drop('price', axis=1)
y = df['price']

# %%
x
# Out:
#          model  year transmission  mileage fuelType  tax   mpg  engineSize
# 0       Fiesta  2017    Automatic    15944   Petrol  150  57.7         1.0
# 1        Focus  2018       Manual     9083   Petrol  150  57.7         1.0
# 2        Focus  2017       Manual    12456   Petrol  150  57.7         1.0
# 3       Fiesta  2019       Manual    10460   Petrol  145  40.3         1.5
# 4       Fiesta  2019    Automatic     1482   Petrol  145  48.7         1.0
# ...        ...   ...          ...      ...      ...  ...   ...         ...
# 17961    B-MAX  2017       Manual    16700   Petrol  150  47.1         1.4
# 17962    B-MAX  2014       Manual    40700   Petrol   30  57.7         1.0
# 17963    Focus  2015       Manual     7010   Diesel   20  67.3         1.6
# 17964       KA  2018       Manual     5007   Petrol  145  57.7         1.2
# 17965    Focus  2015       Manual     5007   Petrol   22  57.7         1.0
#
# [17966 rows x 8 columns]

# %%
y
# Out:
# 0        12000
# 1        14000
# 2        13000
# 3        17500
# 4        16500
#          ...
# 17961     8999
# 17962     7499
# 17963     9999
# 17964     8299
# 17965     8299
# Name: price, Length: 17966, dtype: int64

# %%
x_oneencoded = pd.get_dummies(x, columns=['model', 'transmission', 'fuelType'], drop_first=True)
x_oneencoded.head()
# Out:
#    year  mileage  tax  ...  fuelType_Hybrid  fuelType_Other  fuelType_Petrol
# 0  2017    15944  150  ...            False           False             True
# 1  2018     9083  150  ...            False           False             True
# 2  2017    12456  150  ...            False           False             True
# 3  2019    10460  145  ...            False           False             True
# 4  2019     1482  145  ...            False           False             True
#
# [5 rows x 34 columns]

# %%
x_oneencoded = x_oneencoded.astype(int)
x_oneencoded.head()
# Out:
#    year  mileage  tax  ...  fuelType_Hybrid  fuelType_Other  fuelType_Petrol
# 0  2017    15944  150  ...                0               0                1
# 1  2018     9083  150  ...                0               0                1
# 2  2017    12456  150  ...                0               0                1
# 3  2019    10460  145  ...                0               0                1
# 4  2019     1482  145  ...                0               0                1
#
# [5 rows x 34 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encode = LabelEncoder()

columns_to_encode = ['model', 'transmission', 'fuelType']
for col in columns_to_encode:
    x[col] = encode.fit_transform(x[col])

x.head()
# Out:
#    model  year  transmission  mileage  fuelType  tax   mpg  engineSize
# 0      5  2017             0    15944         4  150  57.7         1.0
# 1      6  2018             1     9083         4  150  57.7         1.0
# 2      6  2017             1    12456         4  150  57.7         1.0
# 3      5  2019             1    10460         4  145  40.3         1.5
# 4      5  2019             0     1482         4  145  48.7         1.0

# %%
# Standardize the features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# Scale the numeric columns
numeric_columns = ['year', 'mileage', 'engineSize', 'tax', 'mpg']
x_oneencoded[numeric_columns] = scaler.fit_transform(x_oneencoded[numeric_columns])
x_oneencoded.head()
# Out:
#        year   mileage  ...  fuelType_Other  fuelType_Petrol
# 0  0.065128 -0.380998  ...               0                1
# 1  0.552866 -0.733359  ...               0                1
# 2  0.065128 -0.560132  ...               0                1
# 3  1.040605 -0.662640  ...               0                1
# 4  1.040605 -1.123724  ...               0                1
#
# [5 rows x 34 columns]

# %%
# Scale the numeric columns in the original dataframe as well
x[numeric_columns] = scaler.fit_transform(x[numeric_columns])
x.head()
# Out:
#    model      year  transmission  ...       tax       mpg  engineSize
# 0      5  0.065128             0  ...  0.591358 -0.020442   -0.811386
# 1      6  0.552866             1  ...  0.591358 -0.020442   -0.811386
# 2      6  0.065128             1  ...  0.591358 -0.020442   -0.811386
# 3      5  1.040605             1  ...  0.510727 -1.738890    0.345070
# 4      5  1.040605             0  ...  0.510727 -0.909294   -0.811386
#
# [5 rows x 8 columns]

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x_oneencoded, y, test_size=0.2, random_state=42)
x_train_orig, x_test_orig, y_train_orig, y_test_orig = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([ 6866.3580764 ,  9347.6810129 ,  9362.18320785, ...,
#        31454.95287518,  9781.20362786, 15253.49970894], shape=(3594,))

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.8464177711972798

# %%
model2 = LinearRegression()
model2.fit(x_train_orig, y_train_orig)
# Out:
# LinearRegression()

# %%
y_pred2 = model2.predict(x_test_orig)
y_pred2
# Out:
# array([ 6152.07567671,  9374.39134399,  9464.92264335, ...,
#        21787.05312508,  9776.43926374, 15806.24990719], shape=(3594,))

# %%
r2_score2 = r2_score(y_test_orig, y_pred2)
r2_score2
# Out:
# 0.7365884288851352
